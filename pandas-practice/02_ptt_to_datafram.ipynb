# %%
from pathlib import Path
import pandas as pd

# %%
res_gossiping_path = Path("res_gossiping")

# %%
res_gossiping_path
# Out:
# PosixPath('res_gossiping')

# %%
res_gossiping_path.glob("*.txt")

# %%
for file_path in res_gossiping_path.glob("*.txt"):
    print(file_path)
# Out:
# res_gossiping/[問卦] 兩個候選人選前一個月同時陣亡的可能性.txt
# res_gossiping/[新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵.txt
# res_gossiping/[問卦] 如果川普老婆死於武漢肺炎會怎麼樣？.txt
# res_gossiping/[問卦] 為什麼古代生物體型可以長到這麼大？.txt
# res_gossiping/[問卦] 支那女生是不是都沒錢修補衣服.txt
# res_gossiping/[新聞] 川普夫婦確診了！網友卻認為「案情不單.txt
# res_gossiping/[問卦] 習大大現在在想什麼.txt
# res_gossiping/[新聞] 國際藝文人士來台可申請專案縮短隔離 國.txt
# res_gossiping/[問卦] 隨便說三個你會的做愛技巧！.txt
# res_gossiping/[問卦] 亡國之君在想什麼？.txt
# res_gossiping/[問卦] 現在新聞都喜歡用什麼字眼啊.txt
# res_gossiping/[問卦] 你第一眼直覺這個能防螞蟻嗎.txt
# res_gossiping/[問卦] (更新肉包) 大安區的便當這樣多少？.txt
# res_gossiping/[問卦] 泌尿科找女醫師，最後向台女露鳥的機會？.txt
# res_gossiping/[新聞] 新莊、樹林周邊電桿全面地下化 耗資9億54.txt
# res_gossiping/[新聞] 印度邊境布防巡航導彈目標鎖解放軍西藏.txt
# res_gossiping/[問卦] 華堡是不是屌打大麥克.txt
# res_gossiping/[新聞] 扯！台中發獎狀竟印中國民國　師：原來.txt
# res_gossiping/[問卦] 台灣的印度人多嗎.txt
# res_gossiping/[問卦] 川普遺書會寫什麼？.txt
# res_gossiping/[問卦] 以後下基地會全部都是教召老兵嗎_.txt
# res_gossiping/[問卦] 阿福一字馬484很香啊？.txt
# res_gossiping/[問卦] 有沒有國慶煙火超屌的八卦？.txt
# res_gossiping/[問卦] 那些質疑魏如萱的是否沒看到這段才質疑.txt
# ...

# %%
for file_path in res_gossiping_path.glob("*.txt"):
    print(file_path)
# Out:
# res_gossiping/[問卦] 兩個候選人選前一個月同時陣亡的可能性.txt
# res_gossiping/[新聞]江啟臣：兩岸是不對稱的戰爭 從募兵改徵兵.txt
# res_gossiping/[問卦] 如果川普老婆死於武漢肺炎會怎麼樣？.txt
# res_gossiping/[問卦] 為什麼古代生物體型可以長到這麼大？.txt
# res_gossiping/[問卦] 支那女生是不是都沒錢修補衣服.txt
# res_gossiping/[新聞] 川普夫婦確診了！網友卻認為「案情不單.txt
# res_gossiping/[問卦] 習大大現在在想什麼.txt
# res_gossiping/[新聞] 國際藝文人士來台可申請專案縮短隔離 國.txt
# res_gossiping/[問卦] 隨便說三個你會的做愛技巧！.txt
# res_gossiping/[問卦] 亡國之君在想什麼？.txt
# res_gossiping/[問卦] 現在新聞都喜歡用什麼字眼啊.txt
# res_gossiping/[問卦] 你第一眼直覺這個能防螞蟻嗎.txt
# res_gossiping/[問卦] (更新肉包) 大安區的便當這樣多少？.txt
# res_gossiping/[問卦] 泌尿科找女醫師，最後向台女露鳥的機會？.txt
# res_gossiping/[新聞] 新莊、樹林周邊電桿全面地下化 耗資9億54.txt
# res_gossiping/[新聞] 印度邊境布防巡航導彈目標鎖解放軍西藏.txt
# res_gossiping/[問卦] 華堡是不是屌打大麥克.txt
# res_gossiping/[新聞] 扯！台中發獎狀竟印中國民國　師：原來.txt
# res_gossiping/[問卦] 台灣的印度人多嗎.txt
# res_gossiping/[問卦] 川普遺書會寫什麼？.txt
# res_gossiping/[問卦] 以後下基地會全部都是教召老兵嗎_.txt
# res_gossiping/[問卦] 阿福一字馬484很香啊？.txt
# res_gossiping/[問卦] 有沒有國慶煙火超屌的八卦？.txt
# res_gossiping/[問卦] 那些質疑魏如萱的是否沒看到這段才質疑.txt
# ...

# %%
Path("res_gossiping")
# Out:
# PosixPath('res_gossiping')

# %%
print(Path("res_gossiping").resolve())
# Out:
# /Users/uuboy.scy/side-project/tibame/tkr102/pandas-practice/res_gossiping
